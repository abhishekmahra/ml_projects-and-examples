# %% [markdown]
# <a href="https://colab.research.google.com/github/abhishekmahra/ml_projects-and-examples/blob/main/sentimentalanalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pip install newspaper3k
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.1/211.1 kB 5.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.9/92.9 kB 5.2 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 59.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.1/81.1 kB 5.0 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for tinysegmenter: filename=tinysegmenter-0.3-py3-none-any.whl size=13552 sha256=a41ba16a1ec80617e25c7c3ada2e86940d4d6aa8be01e24aa508dcbe76228dec
#   Stored in directory: /root/.cache/pip/wheels/c8/d6/6c/384f58df48c00b9a31d638005143b5b3ac62c3d25fb1447f23
# ...

# %%
from newspaper import Article
import nltk

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-5203ea8e-b199-4edb-9d64-3e6920a1f14e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5203ea8e-b199-4edb-9d64-3e6920a1f14e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_excel('input.xlsx')

# %%
df
# Out:
#      URL_ID                                                URL
# 0        38  https://insights.blackcoffer.com/ai-in-healthc...
# 1        39  https://insights.blackcoffer.com/what-if-the-c...
# 2        40  https://insights.blackcoffer.com/what-jobs-wil...
# 3        41  https://insights.blackcoffer.com/will-machine-...
# 4        42  https://insights.blackcoffer.com/will-ai-repla...
# ..      ...                                                ...
# 105     143  https://insights.blackcoffer.com/blockchain-fo...
# 106     144  https://insights.blackcoffer.com/the-future-of...
# 107     145  https://insights.blackcoffer.com/big-data-anal...
# 108     146  https://insights.blackcoffer.com/business-anal...
# 109     147  https://insights.blackcoffer.com/challenges-an...
#
# [110 rows x 2 columns]

# %%
url = 'https://insights.blackcoffer.com/ai-in-healthcare-to-improve-patient-outcomes/'
article = Article(url, language="en")

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
article.download() 
article.parse() 
article.nlp()

# %% [markdown]
# taking summary of the article provided in a single url!
# by finding its title,its text,its sumarry and article keywords!

# %%
print("Article Title:") 
print(article.title) #prints the title of the article
print("\n") 
print("Article Text:") 
print(article.text) #prints the entire text of the article
print("\n") 
print("Article Summary:") 
print(article.summary) #prints the summary of the article
print("\n") 
print("Article Keywords:")
print(article.keywords) #prints the keywords of the article
# Out:
# Article Title:
# AI in healthcare to Improve Patient Outcomes
#
#
# Article Text:
# Introduction
#
# “If anything kills over 10 million people in the next few decades, it will be a highly infectious virus rather than a war. Not missiles but microbes.” Bill Gates’s remarks at a TED conference in 2014, right after the world had avoided the Ebola outbreak. When the new, unprecedented, invisible virus hit us, it met an overwhelmed and unprepared healthcare system and oblivious population. This public health emergency demonstrated our lack of scientific consideration and underlined the alarming need for robust innovations in our health and medical facilities. For the past few years, artificial intelligence has proven to be of tangible potential in the healthcare sectors, clinical practices, translational medical and biomedical research.
#
# ...

# %% [markdown]
# *   now making a function tht can get text from any url

# %%
def get_text(url):
    
    url1 = url
    article = Article(url1, language="en")
    
    article.download() 
    article.parse() 
    article.nlp()
    
    return article.text

# %% [markdown]
# *   now taking all urls one by one and getting texts ouf ot if

# %%
for i in range(0,len(df)):
    df['URL_ID'][i] = get_text(df['URL'][i])
# Out:
# <ipython-input-12-3d5836659288>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['URL_ID'][i] = get_text(df['URL'][i])

# %%
df.rename({'URL_ID':'Text'},axis=1,inplace=True)   #renaming the column URL_ID to text

# %%
df.head(10)
# Out:
#                                                 Text  \
# 0  Introduction\n\n“If anything kills over 10 mil...
# 1  Human minds, a fascination in itself carrying ...
# 2  Introduction\n\nAI is rapidly evolving in the ...
# 3  “Anything that could give rise to smarter-than...
# 4  “Machine intelligence is the last invention th...
# 5  Introduction\n\nWhere is this disruptive techn...
# 6  In future or in upcoming years humans and mach...
# 7  Machine learning techniques may have been used...
# 8  eLearning as technology becomes more affordabl...
# 9  Before the internet, information was in some w...
#
#                                                  URL
# 0  https://insights.blackcoffer.com/ai-in-healthc...
# 1  https://insights.blackcoffer.com/what-if-the-c...
# 2  https://insights.blackcoffer.com/what-jobs-wil...
# 3  https://insights.blackcoffer.com/will-machine-...
# 4  https://insights.blackcoffer.com/will-ai-repla...
# 5  https://insights.blackcoffer.com/man-and-machi...
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# *   getting differnt different stop words files into a single string named as stop_words

# %%
stop_words_files = ["/content/StopWords_Auditor.txt", "/content/StopWords_Currencies.txt", "/content/StopWords_DatesandNumbers.txt","/content/StopWords_Generic.txt","/content/StopWords_GenericLong.txt","/content/StopWords_Geographic.txt","/content/StopWords_Names.txt"] # list of stop words file paths
stop_words = []

for stop_words_file in stop_words_files:
    with open(stop_words_file, "r",encoding="iso-8859-1") as f:
        for line in f:
            stop_words.append(line.strip())

print(stop_words)
# Out:
# ['ERNST', 'YOUNG', 'DELOITTE', 'TOUCHE', 'KPMG', 'PRICEWATERHOUSECOOPERS', 'PRICEWATERHOUSE', 'COOPERS', 'AFGHANI  | Afghanistan', 'ARIARY | Madagascar', 'BAHT | Thailand', 'BALBOA | Panama', 'BIRR | Ethiopia', 'BOLIVAR | Venezuela', 'BOLIVIANO  | Bolivia', 'CEDI | Ghana', 'COLON  | Costa Rica', 'CÓRDOBA  | Nicaragua', 'DALASI | Gambia', 'DENAR | Macedonia (Former Yug. Rep.)', 'DINAR | Algeria', 'DIRHAM  | Morocco', 'DOBRA | São Tom and Príncipe', 'DONG | Vietnam', 'DRAM | Armenia', 'ESCUDO  | Cape Verde', 'EURO  | Belgium', 'FLORIN | Aruba', 'FORINT | Hungary', 'GOURDE | Haiti', 'GUARANI | Paraguay', 'GULDEN | Netherlands Antilles', 'HRYVNIA  | Ukraine', 'KINA | Papua New Guinea', 'KIP | Laos', 'KONVERTIBILNA MARKA  | Bosnia-Herzegovina', 'KORUNA  | Czech Republic', 'KRONA | Sweden', 'KRONE | Denmark', 'KROON | Estonia', 'KUNA | Croatia', 'KWACHA | Zambia', 'KWANZA | Angola', 'KYAT | Myanmar', 'LARI | Georgia', 'LATS | Latvia', 'LEK | Albania', 'LEMPIRA | Honduras', 'LEONE | Sierra 
# ...

# %%
import re
def transform(text):
    review = re.sub('[^a-zA-Z0-9]', ' ',text)
    review = review.lower()
    review = review.split()
    review = [word for word in review if word not in stop_words]
    review = ' '.join(review)
    return review

df['Transform_Text'] = df['Text'].apply(transform)

# %%
df
# Out:
#                                                   Text  \
# 0    Introduction\n\n“If anything kills over 10 mil...
# 1    Human minds, a fascination in itself carrying ...
# 2    Introduction\n\nAI is rapidly evolving in the ...
# 3    “Anything that could give rise to smarter-than...
# 4    “Machine intelligence is the last invention th...
# ..                                                 ...
# 105  Reconciling with the financial realities of an...
# 106  What Is an Investment?\n\nAn investment is a r...
# 107  Quality and affordable healthcare is a vision ...
# 108  Analytics is a statistical scientific process ...
# 109  Big Data\n\nTo begin with I shall first like t...
#
#                                                    URL  \
# 0    https://insights.blackcoffer.com/ai-in-healthc...
# 1    https://insights.blackcoffer.com/what-if-the-c...
# 2    https://insights.blackcoffer.com/what-jobs-wil...
# 3    https://insights.blackcoffer.com/will-machine-...
# ...

# %% [markdown]
# Data Analysis
# For each of the extracted texts from the article, perform textual analysis and compute variables.
#
# I am looking for these variables in the analysis document:
#
# POSITIVE SCORE
#
# NEGATIVE SCORE
#
# POLARITY SCORE
#
# SUBJECTIVITY SCORE
#
# AVG SENTENCE LENGTH
#
# PERCENTAGE OF COMPLEX WORDS
#
# FOG INDEX
#
# AVG NUMBER OF WORDS PER SENTENCE
#
# COMPLEX WORD COUNT
#
# WORD COUNT
#
# SYLLABLE PER WORD
#
# PERSONAL PRONOUNS
#
# AVG WORD LENGTH

# %% [markdown]
# ##word count for each text

# %%
# word count in each text row.

df['word_counts'] = df['Transform_Text'].apply(lambda x: len(str(x).split()))

# %%
len(nltk.sent_tokenize(df['Text'][0]))  # checking length function
# Out:
# 77

# %%
import numpy as np

df['average number of words per sentence'] = np.nan

for i in range(0,len(df)):
    
    df['average number of words per sentence'][i] = df['word_counts'][i]/len(nltk.sent_tokenize(df['Text'][i]))
# Out:
# <ipython-input-22-be5e6c99d8b2>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['average number of words per sentence'][i] = df['word_counts'][i]/len(nltk.sent_tokenize(df['Text'][i]))

# %%
df.head(5)
# Out:
#                                                 Text  \
# 0  Introduction\n\n“If anything kills over 10 mil...
# 1  Human minds, a fascination in itself carrying ...
# 2  Introduction\n\nAI is rapidly evolving in the ...
# 3  “Anything that could give rise to smarter-than...
# 4  “Machine intelligence is the last invention th...
#
#                                                  URL  \
# 0  https://insights.blackcoffer.com/ai-in-healthc...
# 1  https://insights.blackcoffer.com/what-if-the-c...
# 2  https://insights.blackcoffer.com/what-jobs-wil...
# 3  https://insights.blackcoffer.com/will-machine-...
# 4  https://insights.blackcoffer.com/will-ai-repla...
#
#                                       Transform_Text  word_counts  \
# 0  introduction kills 10 million people decades h...         1049
# 1  human minds fascination carrying potential tin...          622
# 2  introduction ai rapidly evolving employment se...          879
# ...

# %% [markdown]
# ##finding chara count!

# %%
def char_count(x):
    s = x.split()
    x = ''.join(s)
    return len(x)      # counting the total number of characters in each text data.

# %%
#chara count
df['chara_count'] = df['Transform_Text'].apply(lambda x: char_count(x))

# %%
df['stopwords'] = df['Text'].apply(lambda x: [t for t in x.split() if t in stop_words])

# %%
df['average word length'] = np.nan

for i in range(0,len(df)):
    
    df['average word length'][i] = df['chara_count'][i]/df['word_counts'][i]
# Out:
# <ipython-input-27-2b95d69bd553>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['average word length'][i] = df['chara_count'][i]/df['word_counts'][i]

# %%
df
# Out:
#                                                   Text  \
# 0    Introduction\n\n“If anything kills over 10 mil...
# 1    Human minds, a fascination in itself carrying ...
# 2    Introduction\n\nAI is rapidly evolving in the ...
# 3    “Anything that could give rise to smarter-than...
# 4    “Machine intelligence is the last invention th...
# ..                                                 ...
# 105  Reconciling with the financial realities of an...
# 106  What Is an Investment?\n\nAn investment is a r...
# 107  Quality and affordable healthcare is a vision ...
# 108  Analytics is a statistical scientific process ...
# 109  Big Data\n\nTo begin with I shall first like t...
#
#                                                    URL  \
# 0    https://insights.blackcoffer.com/ai-in-healthc...
# 1    https://insights.blackcoffer.com/what-if-the-c...
# 2    https://insights.blackcoffer.com/what-jobs-wil...
# 3    https://insights.blackcoffer.com/will-machine-...
# ...

# %% [markdown]
# SYLLABLE COUNT:
# We count the number of Syllables in each word of the text by counting the vowels present in each word.

# %%
h=df
def syllable_count(x):
    v = []
    d = {}
    for i in x:
        if i in "aeiou":
            v.append(i)
            d[i] = d.get(i,0)+1
            
    k = []
    for i in d:
        k.append(d[i])

    return np.sum(k)

g = h['Transform_Text'][1]

syllable_count(g)
# Out:
# 1605

# %%
df['syllable per word count'] = df['Transform_Text'].apply(lambda x: syllable_count(x))
df
# Out:
#                                                   Text  \
# 0    Introduction\n\n“If anything kills over 10 mil...
# 1    Human minds, a fascination in itself carrying ...
# 2    Introduction\n\nAI is rapidly evolving in the ...
# 3    “Anything that could give rise to smarter-than...
# 4    “Machine intelligence is the last invention th...
# ..                                                 ...
# 105  Reconciling with the financial realities of an...
# 106  What Is an Investment?\n\nAn investment is a r...
# 107  Quality and affordable healthcare is a vision ...
# 108  Analytics is a statistical scientific process ...
# 109  Big Data\n\nTo begin with I shall first like t...
#
#                                                    URL  \
# 0    https://insights.blackcoffer.com/ai-in-healthc...
# 1    https://insights.blackcoffer.com/what-if-the-c...
# 2    https://insights.blackcoffer.com/what-jobs-wil...
# 3    https://insights.blackcoffer.com/will-machine-...
# ...

# %% [markdown]
# COMPLEX Word Count
# Complex words are words in the text that contain more than two Syllables.

# %%
from collections import  Counter

def complex_word_count(x):
    
    syllable = 'aeiou'
    
    t = x.split()
    
    v = []
    
    for i in t:
        words = i.split()
        c=Counter()
        
        for word in words:
            c.update(set(word))

        n = 0
        for a in c.most_common():
            if a[0] in syllable:
                if a[1] >= 2:
                    n += 1
                
        m = 0
        p = []
        for a in c.most_common():
            if a[0] in syllable:
                p.append(a[0])
        if len(p) >= 2:
            m += 1
        
        if n >= 1 or m >= 1:
            v.append(i)
            
    return len(v) 

g = h['Transform_Text'][1]

complex_word_count(g)
# Out:
# 460

# %%
df['complex_count'] = np.nan

df['complex_count'] = df['Transform_Text'].apply(lambda x: complex_word_count(x))
df.head()
# Out:
#                                                 Text  \
# 0  Introduction\n\n“If anything kills over 10 mil...
# 1  Human minds, a fascination in itself carrying ...
# 2  Introduction\n\nAI is rapidly evolving in the ...
# 3  “Anything that could give rise to smarter-than...
# 4  “Machine intelligence is the last invention th...
#
#                                                  URL  \
# 0  https://insights.blackcoffer.com/ai-in-healthc...
# 1  https://insights.blackcoffer.com/what-if-the-c...
# 2  https://insights.blackcoffer.com/what-jobs-wil...
# 3  https://insights.blackcoffer.com/will-machine-...
# 4  https://insights.blackcoffer.com/will-ai-repla...
#
#                                       Transform_Text  word_counts  \
# 0  introduction kills 10 million people decades h...         1049
# 1  human minds fascination carrying potential tin...          622
# 2  introduction ai rapidly evolving employment se...          879
# ...

# %% [markdown]
# Analysis of Readability
# Analysis of Readability is calculated using the Gunning Fox index formula described below.
#
# Average Sentence Length = the number of words / the number of sentences
#
# Percentage of Complex words = the number of complex words / the number of words
#
# Fog Index = 0.4 * (Average Sentence Length + Percentage of Complex words)

# %%
df['sentence length'] = np.nan
df['Average Sentence Length'] = np.nan
df['Percentage of Complex words'] = np.nan
df['Fog Index'] = np.nan


for i in range(0,len(df)):
    
    df['sentence length'][i]  =   len(nltk.sent_tokenize(df['Text'][i]))
    df['Average Sentence Length'][i] = df['word_counts'][i]/df['sentence length'][i]
    df['Percentage of Complex words'][i] = df['complex_count'][i]/df['word_counts'][i] 
    df['Fog Index'][i] = 0.4 * (df['Average Sentence Length'][i] + df['Percentage of Complex words'][i])
# Out:
# <ipython-input-33-b2c86d949a96>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sentence length'][i]  =   len(nltk.sent_tokenize(df['Text'][i]))
# <ipython-input-33-b2c86d949a96>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Average Sentence Length'][i] = df['word_counts'][i]/df['sentence length'][i]
# <ipython-input-33-b2c86d949a96>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df.head()
# Out:
#                                                 Text  \
# 0  Introduction\n\n“If anything kills over 10 mil...
# 1  Human minds, a fascination in itself carrying ...
# 2  Introduction\n\nAI is rapidly evolving in the ...
# 3  “Anything that could give rise to smarter-than...
# 4  “Machine intelligence is the last invention th...
#
#                                                  URL  \
# 0  https://insights.blackcoffer.com/ai-in-healthc...
# 1  https://insights.blackcoffer.com/what-if-the-c...
# 2  https://insights.blackcoffer.com/what-jobs-wil...
# 3  https://insights.blackcoffer.com/will-machine-...
# 4  https://insights.blackcoffer.com/will-ai-repla...
#
#                                       Transform_Text  word_counts  \
# 0  introduction kills 10 million people decades h...         1049
# 1  human minds fascination carrying potential tin...          622
# 2  introduction ai rapidly evolving employment se...          879
# ...

# %% [markdown]
# SENTIMENT ANALYSIS
# Sentimental analysis is the process of determining whether a piece of writing is positive, negative or neutral.

# %%
# Load the negative and positive word lists
with open('negative-words.txt', 'r',encoding="iso-8859-1") as f:
    negative_words = f.read().split()

with open('positive-words.txt', 'r',encoding="iso-8859-1") as f:
    positive_words = f.read().split()

# %%
def get_sentiment_scores(text):
    # Split the text into words
    words = text.lower().split()
    
    # Calculate the number of positive and negative words in the text
    num_positive_words = sum(1 for word in words if word in positive_words)
    num_negative_words = sum(1 for word in words if word in negative_words)
    
    # Calculate the polarity score
    if num_positive_words + num_negative_words == 0:
        polarity_score = 0
    else:
        polarity_score = (num_positive_words - num_negative_words) / (num_positive_words + num_negative_words)
    
    # Return the positive and negative scores and polarity score as a tuple
    return num_positive_words, num_negative_words, polarity_score

# %% [markdown]
# ##getting positive score,negative score,polarity score of all the urls and updating them in the dataframe!

# %%
df['Positive_Score'], df['Negative_Score'], df['Polarity_Score'] = zip(*df['Transform_Text'].apply(get_sentiment_scores))
df.head()
# Out:
#                                                 Text  \
# 0  Introduction\n\n“If anything kills over 10 mil...
# 1  Human minds, a fascination in itself carrying ...
# 2  Introduction\n\nAI is rapidly evolving in the ...
# 3  “Anything that could give rise to smarter-than...
# 4  “Machine intelligence is the last invention th...
#
#                                                  URL  \
# 0  https://insights.blackcoffer.com/ai-in-healthc...
# 1  https://insights.blackcoffer.com/what-if-the-c...
# 2  https://insights.blackcoffer.com/what-jobs-wil...
# 3  https://insights.blackcoffer.com/will-machine-...
# 4  https://insights.blackcoffer.com/will-ai-repla...
#
#                                       Transform_Text  word_counts  \
# 0  introduction kills 10 million people decades h...         1049
# 1  human minds fascination carrying potential tin...          622
# 2  introduction ai rapidly evolving employment se...          879
# ...

# %% [markdown]
# SUBJECTIVITY SCORE
# Subjectivity Score: This is the score that determines if a given text is objective or subjective.
#
# It is calculated by using the formula:
#
# Subjectivity Score = (Positive Score + Negative Score)/ ((Total Words after cleaning) + 0.000001)
#
# Range is from 0 to +1

# %%
from textblob import TextBlob

# %%
blob = TextBlob(df['Transform_Text'][1])
blob.sentiment
# Out:
# Sentiment(polarity=0.021257378984651704, subjectivity=0.41450241046831965)

# %%
TextBlob(df['Transform_Text'][1]).sentiment[1]
# Out:
# 0.41450241046831965

# %%
df['subjectivity'] = np.nan

for i in range(len(df)):
    df['subjectivity'][i] = TextBlob(df['Transform_Text'][i]).sentiment[1]                                                                                                                                                                                                                                                                                                                                                                                                                                                           `
# Out:
# <ipython-input-44-e2ef106e9ec3>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['subjectivity'][i] = TextBlob(df['Transform_Text'][i]).sentiment[1]

# %%
df
# Out:
#                                                   Text  \
# 0    Introduction\n\n“If anything kills over 10 mil...
# 1    Human minds, a fascination in itself carrying ...
# 2    Introduction\n\nAI is rapidly evolving in the ...
# 3    “Anything that could give rise to smarter-than...
# 4    “Machine intelligence is the last invention th...
# ..                                                 ...
# 105  Reconciling with the financial realities of an...
# 106  What Is an Investment?\n\nAn investment is a r...
# 107  Quality and affordable healthcare is a vision ...
# 108  Analytics is a statistical scientific process ...
# 109  Big Data\n\nTo begin with I shall first like t...
#
#                                                    URL  \
# 0    https://insights.blackcoffer.com/ai-in-healthc...
# 1    https://insights.blackcoffer.com/what-if-the-c...
# 2    https://insights.blackcoffer.com/what-jobs-wil...
# 3    https://insights.blackcoffer.com/will-machine-...
# ...

# %% [markdown]
# PERSONAL PRONOUNS
# To calculate Personal Pronouns mentioned in the text, we use regex to find the counts of the words - “I,” “we,” “my,” “ours,” and “us”.

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
df['PERSONAL PRONOUNS'] = np.nan
doc = nlp(df['Text'][1])
tok = []
for token in doc:
    if token.pos_ == 'PRON':
        tok.append(token)
tok
# Out:
# [itself,
#  anything,
#  it,
#  It,
#  something,
#  it,
#  this,
#  what,
#  them,
#  what,
#  there,
#  something,
#  that,
#  their,
#  them,
#  their,
#  themselves,
#  it,
#  their,
#  its,
#  themselves,
#  it,
#  this,
#  another,
#  who,
#  himself,
#  him,
#  It,
#  Something,
#  that,
#  his,
#  something,
#  that,
#  him,
#  it,
#  it,
#  it,
#  it,
#  that,
#  its,
#  it,
#  This,
#  they,
#  it,
#  it,
#  their,
#  it,
#  it,
#  it,
#  that,
#  There,
#  it,
#  Nobody,
#  it,
#  that,
#  we,
#  it,
#  their,
#  it,
#  their,
#  us,
#  that,
#  us,
#  our,
#  that,
#  they,
#  what,
#  it,
#  it,
#  it,
#  that,
#  it,
#  its,
#  one,
#  it,
#  It,
#  there,
#  ourselves,
#  it,
#  They,
#  that,
#  their,
#  their,
#  They,
#  their,
#  it,
#  it,
#  its,
#  it,
#  it,
#  their,
#  it,
#  who,
#  No,
#  there,
#  something,
#  that,
#  us,
#  who,
#  who,
#  who,
#  who,
#  there,
#  nothing,
#  we,
#  ’s,
#  our,
#  ourselves,
#  this,
#  all,
#  we]

# %%
df['PERSONAL PRONOUNS'][1] = tok
df.head()
# Out:
# <ipython-input-48-811041ecb501>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['PERSONAL PRONOUNS'][1] = tok
#                                                 Text  \
# 0  Introduction\n\n“If anything kills over 10 mil...
# 1  Human minds, a fascination in itself carrying ...
# 2  Introduction\n\nAI is rapidly evolving in the ...
# 3  “Anything that could give rise to smarter-than...
# 4  “Machine intelligence is the last invention th...
#
#                                                  URL  \
# 0  https://insights.blackcoffer.com/ai-in-healthc...
# 1  https://insights.blackcoffer.com/what-if-the-c...
# 2  https://insights.blackcoffer.com/what-jobs-wil...
# 3  https://insights.blackcoffer.com/will-machine-...
# 4  https://insights.blackcoffer.com/will-ai-repla...
#
# ...

# %%
df['PERSONAL PRONOUNS'] = np.nan

for i in range(len(df)):
    doc = nlp(df['Text'][i])
    tok = []
    for token in doc:
        if token.pos_ == 'PRON':
            tok.append(token)
        
    df['PERSONAL PRONOUNS'][i] = tok
df.head()
# Out:
# <ipython-input-49-8d67432b7b95>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['PERSONAL PRONOUNS'][i] = tok
#                                                 Text  \
# 0  Introduction\n\n“If anything kills over 10 mil...
# 1  Human minds, a fascination in itself carrying ...
# 2  Introduction\n\nAI is rapidly evolving in the ...
# 3  “Anything that could give rise to smarter-than...
# 4  “Machine intelligence is the last invention th...
#
#                                                  URL  \
# 0  https://insights.blackcoffer.com/ai-in-healthc...
# 1  https://insights.blackcoffer.com/what-if-the-c...
# 2  https://insights.blackcoffer.com/what-jobs-wil...
# 3  https://insights.blackcoffer.com/will-machine-...
# 4  https://insights.blackcoffer.com/will-ai-repla...
#
# ...

# %%
df['PERSONAL PRONOUNS'][2]
# Out:
# [their,
#  that,
#  This,
#  that,
#  which,
#  them,
#  It,
#  Its,
#  which,
#  which,
#  which,
#  you,
#  your,
#  they,
#  them,
#  There,
#  which,
#  which,
#  it,
#  it,
#  its,
#  they,
#  their,
#  which,
#  There,
#  it,
#  it,
#  their,
#  it,
#  which,
#  It,
#  which,
#  which,
#  that,
#  its,
#  It,
#  it,
#  We,
#  them,
#  their,
#  It,
#  all,
#  which,
#  This,
#  which,
#  that,
#  It,
#  its,
#  There,
#  which,
#  it,
#  these,
#  There,
#  they,
#  their,
#  It,
#  This,
#  You,
#  There,
#  which,
#  the,
#  everything,
#  which,
#  it,
#  it,
#  it,
#  us,
#  us,
#  themselves,
#  there]

# %% [markdown]
# ##creating a submit dataframe which inclueds all the varibales that were calculated above:

# %%
submit = df[['URL','Positive_Score','Negative_Score','Polarity_Score','subjectivity','Average Sentence Length','Percentage of Complex words',
            'Fog Index','average number of words per sentence','complex_count','word_counts','syllable per word count','PERSONAL PRONOUNS','average word length']]

# %%
submit.head()
# Out:
#                                                  URL  Positive_Score  \
# 0  https://insights.blackcoffer.com/ai-in-healthc...              69
# 1  https://insights.blackcoffer.com/what-if-the-c...              61
# 2  https://insights.blackcoffer.com/what-jobs-wil...              66
# 3  https://insights.blackcoffer.com/will-machine-...              70
# 4  https://insights.blackcoffer.com/will-ai-repla...              63
#
#    Negative_Score  Polarity_Score  subjectivity  Average Sentence Length  \
# 0              36        0.314286      0.447169                13.623377
# 1              37        0.244898      0.414502                 7.775000
# 2              36        0.294118      0.516090                10.341176
# 3              28        0.428571      0.449041                 7.621053
# 4              27        0.400000      0.521347                10.873418
#
#    Percentage of Complex words  Fog Index  \
# 0                     0.829361   5.781095
# ...

# %%
submit.to_excel("Output Data Structure.xlsx", index=False)

# %%
from google.colab import files
files.download("Output Data Structure.xlsx")
